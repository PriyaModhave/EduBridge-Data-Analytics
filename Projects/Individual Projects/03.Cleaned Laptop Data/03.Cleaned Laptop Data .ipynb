# %% [markdown]
# ## Import Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Read the Data

# %%
df=pd.read_csv('Cleaned_Laptop_data.csv')

# %%
df
# Out:
#       brand     model processor_brand processor_name processor_gnrtn ram_gb  \
# 0      ASUS   Celeron           Intel   Celeron Dual         Missing      4
# 1      ASUS  VivoBook           Intel        Core i3            10th      8
# 2      ASUS  Vivobook           Intel        Core i3            10th      8
# 3        HP      Core           Intel        Core i3            11th      8
# 4        HP      Core           Intel        Core i5            11th      8
# ..      ...       ...             ...            ...             ...    ...
# 891    DELL      Core           Intel        Core i3            10th      8
# 892    DELL      Core           Intel        Core i3            10th      8
# 893      HP  Pavilion           Intel        Core i5             8th      8
# 894    ASUS  Vivobook           Intel        Core i3            10th      4
# 895  Lenovo       v15           Intel        Core i3            10th      4
#
# ...

# %% [markdown]
# ## Top 5 records

# %%
df.head()
# Out:
#   brand     model processor_brand processor_name processor_gnrtn ram_gb  \
# 0  ASUS   Celeron           Intel   Celeron Dual         Missing      4
# 1  ASUS  VivoBook           Intel        Core i3            10th      8
# 2  ASUS  Vivobook           Intel        Core i3            10th      8
# 3    HP      Core           Intel        Core i3            11th      8
# 4    HP      Core           Intel        Core i5            11th      8
#
#   ram_type  ssd   hdd       os  ...  display_size  warranty Touchscreen  \
# 0     DDR4    0  1024  Windows  ...          15.6         1          No
# 1     DDR4  512     0  Windows  ...          15.6         1          No
# 2     DDR4    0  1024  Windows  ...          14.1         1          No
# 3     DDR4  512     0  Windows  ...          15.6         1          No
# 4     DDR4  512     0  Windows  ...          15.6         0          No
#
#   msoffice  latest_price old_price discount  star_rating  ratings  reviews
# ...

# %% [markdown]
# ## Bottom 5 records

# %%
df.tail()
# Out:
#       brand     model processor_brand processor_name processor_gnrtn ram_gb  \
# 891    DELL      Core           Intel        Core i3            10th      8
# 892    DELL      Core           Intel        Core i3            10th      8
# 893      HP  Pavilion           Intel        Core i5             8th      8
# 894    ASUS  Vivobook           Intel        Core i3            10th      4
# 895  Lenovo       v15           Intel        Core i3            10th      4
#
#     ram_type  ssd   hdd       os  ...  display_size  warranty Touchscreen  \
# 891     DDR4  256  1024  Windows  ...          15.6         0          No
# 892     DDR4    0  1024  Windows  ...         14.96         0          No
# 893     DDR4  128     0  Windows  ...          13.3         1          No
# 894     DDR4    0  1024  Windows  ...          14.1         0          No
# 895     DDR4    0  1024  Missing  ...          15.6         0          No
#
# ...

# %% [markdown]
# ## Row and Column

# %%
df.shape
# Out:
# (896, 23)

# %% [markdown]
# ## Statistical Information

# %%
df.describe()
# Out:
#                ssd          hdd      os_bit  graphic_card_gb    warranty  \
# count   896.000000   896.000000  896.000000       896.000000  896.000000
# mean    431.750000   190.857143   59.178571         1.198661    0.691964
# std     316.436824   401.181158   11.453644         2.057454    0.606282
# min       0.000000     0.000000   32.000000         0.000000    0.000000
# 25%     256.000000     0.000000   64.000000         0.000000    0.000000
# 50%     512.000000     0.000000   64.000000         0.000000    1.000000
# 75%     512.000000     0.000000   64.000000         2.000000    1.000000
# max    3072.000000  2048.000000   64.000000         8.000000    3.000000
#
#         latest_price      old_price    discount  star_rating       ratings  \
# count     896.000000     896.000000  896.000000   896.000000    896.000000
# mean    76309.860491   88134.154018   18.527902     2.980469    367.391741
# std     46613.354368   55719.645554   10.508486     1.965254   1106.309355
# ...

# %% [markdown]
# ## Field Name

# %%
df.columns
# Out:
# Index(['brand', 'model', 'processor_brand', 'processor_name',
#        'processor_gnrtn', 'ram_gb', 'ram_type', 'ssd', 'hdd', 'os', 'os_bit',
#        'graphic_card_gb', 'weight', 'display_size', 'warranty', 'Touchscreen',
#        'msoffice', 'latest_price', 'old_price', 'discount', 'star_rating',
#        'ratings', 'reviews'],
#       dtype='object')

# %% [markdown]
# ## Unique Value

# %%
df.nunique()
# Out:
# brand               21
# model              120
# processor_brand     11
# processor_name      35
# processor_gnrtn      8
# ram_gb              13
# ram_type            15
# ssd                  8
# hdd                  4
# os                   3
# os_bit               2
# graphic_card_gb      5
# weight               3
# display_size        23
# warranty             4
# Touchscreen          2
# msoffice             2
# latest_price       429
# old_price          564
# discount            48
# star_rating         30
# ratings            310
# reviews            152
# dtype: int64

# %% [markdown]
# ## Seperatly Unique Value

# %%
df['ram_type'].unique()
# Out:
# array(['DDR4', 'DDR5', nan, 'LPDDR4X', 'LPDDR4', 'Unified', 'Full',
#        'LPDDR3', 'DDR3', 'Cooling', 'GTX', 'Master', 'Windows', 'LED',
#        'i5', 'Apps'], dtype=object)

# %%
df['warranty'].unique()
# Out:
# array([1, 0, 2, 3], dtype=int64)

# %% [markdown]
# ## Data type of attributes

# %%
df.dtypes
# Out:
# brand               object
# model               object
# processor_brand     object
# processor_name      object
# processor_gnrtn     object
# ram_gb              object
# ram_type            object
# ssd                  int64
# hdd                  int64
# os                  object
# os_bit               int64
# graphic_card_gb      int64
# weight              object
# display_size        object
# warranty             int64
# Touchscreen         object
# msoffice            object
# latest_price         int64
# old_price            int64
# discount             int64
# star_rating        float64
# ratings              int64
# reviews              int64
# dtype: object

# %% [markdown]
# ## Misssing Value

# %%
df.isnull()
# Out:
#      brand  model  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0    False  False            False           False            False   False
# 1    False  False            False           False            False   False
# 2    False  False            False           False            False   False
# 3    False  False            False           False            False   False
# 4    False  False            False           False            False   False
# ..     ...    ...              ...             ...              ...     ...
# 891  False  False            False           False            False   False
# 892  False  False            False           False            False   False
# 893  False  False            False           False            False   False
# 894  False  False            False           False            False   False
# 895  False  False            False           False            False   False
#
# ...

# %%
df.isnull().sum()
# Out:
# brand               0
# model               0
# processor_brand     0
# processor_name      1
# processor_gnrtn     0
# ram_gb             25
# ram_type           25
# ssd                 0
# hdd                 0
# os                  0
# os_bit              0
# graphic_card_gb     0
# weight              0
# display_size        0
# warranty            0
# Touchscreen         0
# msoffice            0
# latest_price        0
# old_price           0
# discount            0
# star_rating         0
# ratings             0
# reviews             0
# dtype: int64

# %% [markdown]
# ## Clean Null Value

# %%
df=df.drop(['processor_name','ram_gb','ram_type'],axis=1)

# %%
df.isnull().sum()
# Out:
# brand              0
# model              0
# processor_brand    0
# processor_gnrtn    0
# ssd                0
# hdd                0
# os                 0
# os_bit             0
# graphic_card_gb    0
# weight             0
# display_size       0
# warranty           0
# Touchscreen        0
# msoffice           0
# latest_price       0
# old_price          0
# discount           0
# star_rating        0
# ratings            0
# reviews            0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ## Information of a Data set

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 896 entries, 0 to 895
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   brand            896 non-null    object
#  1   model            896 non-null    object
#  2   processor_brand  896 non-null    object
#  3   processor_gnrtn  896 non-null    object
#  4   ssd              896 non-null    int64
#  5   hdd              896 non-null    int64
#  6   os               896 non-null    object
#  7   os_bit           896 non-null    int64
#  8   graphic_card_gb  896 non-null    int64
#  9   weight           896 non-null    object
#  10  display_size     896 non-null    object
#  11  warranty         896 non-null    int64
#  12  Touchscreen      896 non-null    object
#  13  msoffice         896 non-null    object
#  14  latest_price     896 non-null    int64
#  15  old_price        896 non-null    int64
#  16  discount         896 non-null    int64
# ...

# %%
df.duplicated().sum()
# Out:
# 23

# %%
df=df.drop_duplicates()

# %%
df
# Out:
#       brand     model processor_brand processor_gnrtn  ssd   hdd       os  \
# 0      ASUS   Celeron           Intel         Missing    0  1024  Windows
# 1      ASUS  VivoBook           Intel            10th  512     0  Windows
# 2      ASUS  Vivobook           Intel            10th    0  1024  Windows
# 3        HP      Core           Intel            11th  512     0  Windows
# 4        HP      Core           Intel            11th  512     0  Windows
# ..      ...       ...             ...             ...  ...   ...      ...
# 891    DELL      Core           Intel            10th  256  1024  Windows
# 892    DELL      Core           Intel            10th    0  1024  Windows
# 893      HP  Pavilion           Intel             8th  128     0  Windows
# 894    ASUS  Vivobook           Intel            10th    0  1024  Windows
# 895  Lenovo       v15           Intel            10th    0  1024  Missing
#
#      os_bit  graphic_card_gb      weight display_size  warranty Touchscreen  \
# ...

# %% [markdown]
# ## Random lines

# %%
df.sample(4)
# Out:
#     brand       model processor_brand processor_gnrtn  ssd   hdd       os  \
# 794  ASUS    VivoBook             AMD         Missing  512     0  Windows
# 89   acer      Aspire           Intel            11th  256  1024  Windows
# 889  acer  Travelmate           Intel            11th  256  1024  Windows
# 304  DELL    Inspiron           Intel            11th  512     0  Windows
#
#      os_bit  graphic_card_gb  weight display_size  warranty Touchscreen  \
# 794      64                0  Casual         17.3         1          No
# 89       64                0  Casual         15.6         1          No
# 889      64                0  Casual           14         0          No
# 304      64                2  Casual         15.6         1          No
#
#     msoffice  latest_price  old_price  discount  star_rating  ratings  reviews
# 794       No         78000      78990         1          2.7        3        0
# ...

# %% [markdown]
# ##  Correlation

# %%
df.corr()
# Out:
#                       ssd       hdd    os_bit  graphic_card_gb  warranty  \
# ssd              1.000000 -0.467826  0.237452         0.280684  0.201403
# hdd             -0.467826  1.000000 -0.009414        -0.087615 -0.055767
# os_bit           0.237452 -0.009414  1.000000        -0.135363  0.299172
# graphic_card_gb  0.280684 -0.087615 -0.135363         1.000000 -0.050673
# warranty         0.201403 -0.055767  0.299172        -0.050673  1.000000
# latest_price     0.540370 -0.232808 -0.059547         0.494626  0.033001
# old_price        0.483189 -0.254202 -0.008488         0.467466  0.046094
# discount         0.107528 -0.092025  0.042528         0.039236  0.070467
# star_rating     -0.128439  0.031145  0.050310        -0.018882  0.076705
# ratings         -0.186336  0.065125 -0.049618        -0.037959  0.039021
# reviews         -0.188732  0.056269 -0.058485        -0.035708  0.028953
#
#                  latest_price  old_price  discount  star_rating   ratings  \
# ...

# %% [markdown]
# ##  Covariance

# %%
df.cov()
# Out:
#                           ssd           hdd        os_bit  graphic_card_gb  \
# ssd              1.016638e+05 -6.044515e+04    876.472524       185.555661
# hdd             -6.044515e+04  1.642054e+05    -44.163813       -73.611736
# os_bit           8.764725e+02 -4.416381e+01    134.016835        -3.249031
# graphic_card_gb  1.855557e+02 -7.361174e+01     -3.249031         4.298790
# warranty         3.900880e+01 -1.372721e+01      2.103849        -0.063821
# latest_price     8.059276e+06 -4.412792e+06 -32244.641634     47970.195196
# old_price        8.634247e+06 -5.772928e+06  -5506.691384     54318.383317
# discount         3.612507e+02 -3.929183e+02      5.187553         0.857152
# star_rating     -7.988700e+01  2.461979e+01      1.136139        -0.076367
# ratings         -6.350790e+04  2.820899e+04   -613.996028       -84.127258
# reviews         -8.033656e+03  3.044016e+03    -90.386834        -9.883842
#
# ...

# %% [markdown]
# ## Count Number

# %%
df['brand'].value_counts()
# Out:
# ASUS         248
# DELL         153
# Lenovo       148
# HP           142
# acer          58
# MSI           52
# APPLE         23
# Avita          9
# Vaio           5
# realme         4
# Nokia          4
# ALIENWARE      4
# LG             4
# MICROSOFT      3
# Smartron       3
# lenovo         3
# Infinix        3
# RedmiBook      3
# Mi             2
# SAMSUNG        1
# iball          1
# Name: brand, dtype: int64

# %%
df['model'].value_counts()
# Out:
# Core          94
# Inspiron      77
# VivoBook      47
# Vivobook      39
# Pavilion      38
#               ..
# GE76           1
# Commercial     1
# X390           1
# G3             1
# v15            1
# Name: model, Length: 120, dtype: int64

# %%
df['ssd'].value_counts()
# Out:
# 512     407
# 256     189
# 0       151
# 1024    110
# 128      12
# 2048      2
# 3072      1
# 32        1
# Name: ssd, dtype: int64

# %%
df['hdd'].value_counts()
# Out:
# 0       706
# 1024    164
# 512       2
# 2048      1
# Name: hdd, dtype: int64

# %%
df['display_size'].value_counts()
# Out:
# 15.6     381
# 14       267
# 13.3      76
# 0         60
# 17.3      13
# 14.96     11
# 14.1       9
# 16         8
# 16.1       7
# 13         7
# 13.4       7
# 15         6
# 13.5       6
# 16.2       3
# 12.2       3
# 14.2       2
# 14.9       1
# 15.3       1
# All        1
# 6th        1
# 8th        1
# 12         1
# ITW)       1
# Name: display_size, dtype: int64

# %%
d1=df.copy()
d1=d1.pivot_table('latest_price',columns="brand",aggfunc='sum')
d1
# Out:
# brand         ALIENWARE    APPLE      ASUS   Avita     DELL        HP  \
# latest_price    1029460  3612870  19767373  404549  9452624  10193091
#
# brand         Infinix      LG    Lenovo  MICROSOFT  ...      Mi   Nokia  \
# latest_price   130470  303960  10644876     292179  ...  114480  202760
#
# brand         RedmiBook  SAMSUNG  Smartron    Vaio     acer  iball  lenovo  \
# latest_price     130970    38990    148970  278450  4189011  13990  347978
#
# brand         realme
# latest_price  208978
#
# [1 rows x 21 columns]

# %%
d1=df.copy()
d1=d1.pivot_table('latest_price',columns="brand",aggfunc='max')
d1
# Out:
# brand         ALIENWARE   APPLE    ASUS  Avita    DELL      HP  Infinix  \
# latest_price     345390  309990  441990  73990  179990  239759    54990
#
# brand            LG  Lenovo  MICROSOFT  ...     Mi  Nokia  RedmiBook  SAMSUNG  \
# latest_price  86990  265998     100190  ...  59490  55990      48990    38990
#
# brand         Smartron   Vaio    acer  iball  lenovo  realme
# latest_price     52990  62890  169990  13990  171998   60999
#
# [1 rows x 21 columns]

# %%
d1=df.copy()
d1=d1.pivot_table('discount',columns="brand",aggfunc='sum')
d1
# Out:
# brand     ALIENWARE  APPLE  ASUS  Avita  DELL    HP  Infinix   LG  Lenovo  \
# discount         35    167  5164    196  2588  1761       84  121    3622
#
# brand     MICROSOFT  ...  Mi  Nokia  RedmiBook  SAMSUNG  Smartron  Vaio  acer  \
# discount         24  ...  17    152         66       18        16   121  1018
#
# brand     iball  lenovo  realme
# discount     30      71      62
#
# [1 rows x 21 columns]

# %%
n=df.groupby('brand').ratings.sum().sort_values(ascending=False)
n
# Out:
# brand
# ASUS         88562
# HP           75896
# acer         27067
# Lenovo       25437
# realme       19644
# APPLE        19634
# DELL         18904
# MSI          15549
# Avita         5324
# RedmiBook     3834
# Vaio          1763
# Infinix       1661
# Nokia         1247
# iball         1218
# Mi             944
# lenovo         283
# MICROSOFT      114
# LG              83
# Smartron        83
# ALIENWARE       40
# SAMSUNG          0
# Name: ratings, dtype: int64

# %%
n=df.groupby('brand').reviews.sum().sort_values(ascending=False)
n
# Out:
# brand
# ASUS         11384
# HP            8670
# acer          3700
# realme        3038
# Lenovo        3024
# DELL          2184
# MSI           2146
# APPLE         1951
# Avita          803
# RedmiBook      546
# Vaio           354
# Infinix        344
# Nokia          274
# iball          209
# Mi             114
# lenovo          33
# LG              27
# Smartron        19
# MICROSOFT       16
# ALIENWARE        9
# SAMSUNG          0
# Name: reviews, dtype: int64

# %%
df.mean()
# Out:
# <ipython-input-38-c61f0c8f89b5>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# ssd                  433.154639
# hdd                  195.885452
# os_bit                59.051546
# graphic_card_gb        1.225659
# warranty               0.698740
# latest_price       76259.633448
# old_price          88072.953036
# discount              18.632302
# star_rating            3.008591
# ratings              351.989691
# reviews               44.495991
# dtype: float64

# %% [markdown]
# ## Data Visualization:

# %%
df
# Out:
#       brand     model processor_brand processor_gnrtn  ssd   hdd       os  \
# 0      ASUS   Celeron           Intel         Missing    0  1024  Windows
# 1      ASUS  VivoBook           Intel            10th  512     0  Windows
# 2      ASUS  Vivobook           Intel            10th    0  1024  Windows
# 3        HP      Core           Intel            11th  512     0  Windows
# 4        HP      Core           Intel            11th  512     0  Windows
# ..      ...       ...             ...             ...  ...   ...      ...
# 891    DELL      Core           Intel            10th  256  1024  Windows
# 892    DELL      Core           Intel            10th    0  1024  Windows
# 893      HP  Pavilion           Intel             8th  128     0  Windows
# 894    ASUS  Vivobook           Intel            10th    0  1024  Windows
# 895  Lenovo       v15           Intel            10th    0  1024  Missing
#
#      os_bit  graphic_card_gb      weight display_size  warranty Touchscreen  \
# ...

# %%
sns.kdeplot(df['latest_price'],df['discount'],color='green',shade=True)
df
# Out:
# C:\Users\Krishna\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
#       brand     model processor_brand processor_gnrtn  ssd   hdd       os  \
# 0      ASUS   Celeron           Intel         Missing    0  1024  Windows
# 1      ASUS  VivoBook           Intel            10th  512     0  Windows
# 2      ASUS  Vivobook           Intel            10th    0  1024  Windows
# 3        HP      Core           Intel            11th  512     0  Windows
# 4        HP      Core           Intel            11th  512     0  Windows
# ..      ...       ...             ...             ...  ...   ...      ...
# 891    DELL      Core           Intel            10th  256  1024  Windows
# ...

# %%
sns.violinplot(x=df.discount)
plt.show()

# %% [markdown]
# ## Heat map

# %%
sns.heatmap(df.corr())
plt.show()

# %%
sns.heatmap(df.corr(),cmap='RdBu',linewidth=1,square=True)
plt.show()

# %%
print(df['brand'].value_counts())
plt.figure(figsize=(15,4))
sns.countplot(x=df['brand'])
plt.xticks(rotation=90)
plt.show()
# Out:
# ASUS         248
# DELL         153
# Lenovo       148
# HP           142
# acer          58
# MSI           52
# APPLE         23
# Avita          9
# Vaio           5
# realme         4
# Nokia          4
# ALIENWARE      4
# LG             4
# MICROSOFT      3
# Smartron       3
# lenovo         3
# Infinix        3
# RedmiBook      3
# Mi             2
# SAMSUNG        1
# iball          1
# Name: brand, dtype: int64

# %%
print(df['model'].value_counts())
plt.figure(figsize=(30,4))
sns.countplot(x=df['model'])
plt.xticks(rotation=90)
plt.show()
# Out:
# Core          94
# Inspiron      77
# VivoBook      47
# Vivobook      39
# Pavilion      38
#               ..
# GE76           1
# Commercial     1
# X390           1
# G3             1
# v15            1
# Name: model, Length: 120, dtype: int64

# %%
plt.figure(figsize=(25,10))
plt.bar(df['brand'],df['star_rating'],color='yellow')
plt.title('brand Vs star_rating')
plt.xlabel('brand',fontsize=15)
plt.ylabel('star_rating',fontsize=15)
plt.show()
